# %%
# coding: utf-8
import re 
import pandas as pd
import requests
import random
import json
from urllib import parse
from urllib import request
import time
from datetime import datetime
from datetime import timedelta

header={
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36',
    'Connection':'keep-alive'
}

# %%
def get_poet_by_dynasty(Dynasty):
    url = 'https://so.gushiwen.org/authors/Default.aspx?p=1&'
    dict1 ={'c': Dynasty}
    url_data = parse.urlencode(dict1) #unlencode()将字典{k1:v1,k2:v2}转化为k1=v1&k2=v2
    html = requests.get(url=url+url_data, headers=header).content.decode('utf-8')
    
    s0 = r'<div class=\"son1\"><h1>.*?\/ (.*?)页'
    pages = re.findall(s0, html)
    poet=[]
    for i in range(0,int(pages[0])):
        url = 'https://so.gushiwen.org/authors/Default.aspx?p='+str(i+1)+'&'
        dict1 ={'c': Dynasty}
        url_data = parse.urlencode(dict1) #unlencode()将字典{k1:v1,k2:v2}转化为k1=v1&k2=v2
        html = requests.get(url=url+url_data, headers=header).content.decode('utf-8')
        s = r'<a target=\"_blank\" style=.*?<b>(.*?)<\/b>'
        new = re.findall(s, html)
        print(new)
        poet = poet+new      
    return poet

# %%
poems  = get_poet_by_dynasty("唐代")
# Out:
# ['李白', '白居易', '杜甫', '王维', '刘禹锡', '李商隐', '杜牧', '孟浩然', '元稹', '柳宗元']
# ['韩愈', '岑参', '齐己', '贾岛', '韦应物', '温庭筠', '李贺', '刘长卿', '王昌龄', '张籍']
# ['孟郊', '皎然', '许浑', '罗隐', '韦庄', '贯休', '王勃', '陆龟蒙', '张祜', '王建']
# ['姚合', '卢纶', '杜荀鹤', '钱起', '高适', '韩偓', '皮日休', '方干', '李峤', '张九龄']
# ['权德舆', '赵嘏', '皇甫冉', '陈子昂', '郑谷', '戴叔伦', '张说', '吴融', '司空图', '李端']
# ['顾况', '王之涣', '张乔', '贺知章', '马戴', '韩翃', '骆宾王', '宋之问', '崔颢', '李益']
# ['戎昱', '张若虚', '李绅', '李世民', '司空曙', '施肩吾', '储光羲', '朱庆馀', '沈佺期', '常建']
# ['卢照邻', '吕岩', '李颀', '李洞', '鱼玄机', '王翰', '杨巨源', '曹松', '张继', '李德裕']
# ['薛涛', '陈陶', '元结', '杨炯', '李嘉祐', '黄巢', '李涉', '雍陶', '颜真卿', '王湾']
# ['虞世南', '曹邺', '武则天', '刘商', '王绩', '刘方平', '崔涂', '崔护', '崔道融', '张蠙']
# ['羊士谔', '李隆基', '薛逢', '张志和', '高骈', '祖咏', '殷尧藩', '王贞白', '杜审言', '郎士元']
# ['刘希夷', '严维', '陈羽', '汪遵', '张谓', '杜秋娘', '高蟾', '令狐楚', '惠能', '于武陵']
# ['胡令能', '聂夷中', '贾至', '张旭', '秦韬玉', '张泌', '毛文锡', '顾夐', '张仲素', '谭用之']
# ['窦巩', '欧阳炯', '司马扎', '徐彦伯', '裴迪', '刘叉', '林杰', '綦毋潜', '邵谒', '李百药']
# ['卢肇', '杨玉环', '王涯', '雍裕之', '皇甫松', '黄公绍', '章碣', '苏味道', '孟云卿', '牛峤']
# ['郑愔', '魏征', '王驾', '刘昚虚', '江采萍', '李华', '上官仪', '赵彦昭', '李冶', '薛昭蕴']
# ['徐夤', '牛希济', '孟宾于', '蒋贻恭', '黄蘖禅师', '郑遨', '丘为', '柳中庸', '寒山', '郑畋']
# ['崔曙', '李忱', '崔液', '毛熙震', '魏承班', '刘采春', '徐凝', '栖蟾', '卢僎', '李存勖']
# ['李约', '沈如筠', '韦承庆', '金昌绪', '万楚', '李泌', '严武', '郭子仪', '赵蕤', '西鄙人']
# ['武元衡', '包融', '鲍防', '翁宏', '刘庭琦', '孔绍安', '欧阳询', '上官昭容', '崔郊', '狄仁杰']
# ['牛殳', '张巡', '刘皂', '卢汝弼', '刘晏', '颜仁郁', '李昂', '宣宗宫人', '江为', '柳公权']
# ['陈玉兰', '陆羽', '卢仝', '徐铉', '李邕', '宗泽', '李亨', '李阳冰', '罗邺', '喻凫']
# ['徐惠', '陆畅', '张纮', '任华', '张孜', '司马承祯', '文秀', '于鹄', '崔橹', '薛能']
# ['舒元舆', '韦安石', '史青', '辛弘智', '金地藏', '韩溉', '韩琮', '姚崇', '许圉师', '李山甫']
# ['冯道', '崔珏', '项斯', '黄滔', '顾非熊', '杨敬之', '崔国辅', '裴延', '郭震', '李治']
# ['顾非熊', '杨敬之', '裴延', '崔国辅', '郭震', '李治', '周朴', '李群玉', '孟昶', '高力士']
# ['温庭皓', '庄南杰', '张潮', '崔莺莺', '胡曾', '周贺', '王毂', '李昌符', '吕温', '宗楚客']
# ['独孤及', '灵一', '张氲', '朱放', '李遵勖', '宋务光', '拾得', '王缙', '武三思', '吴越人']
# ['柳浑', '耿湋', '许玫', '李季兰', '李旦', '王珪2', '王仲舒', '于良史', '韩熙载', '熊孺登']
# ['宇文融', '柳氏', '颜师古', '王泠然', '吴仁璧', '张建封', '张曙', '释宝月', '王彦威', '崔日用']
# ['孙逖', '李朝威', '李郢', '刘沧', '张敬忠', '韦元甫', '王铎', '刘昫', '王仁裕', '崔融']
# ['周繇', '段穀', '柳郴', '王涣', '夏侯审', '孔德绍', '李真', '吕渭', '李适', '刘三复']
# ['王质', '王镣', '苗晋卿', '王福娘', '张又新', '裴澄', '太上隐者', '钱镠', '朱休', '田游岩']
# ['令狐德棻', '李赤', '李远', '薛戎', '沈亚之', '陈季卿', '于邺', '员半千', '萧颖士', '白敏中']
# ['孙子多', '荆浩', '周祚', '裴夷直', '陈标', '李频', '段成式', '子兰', '李晔', '可朋']
# ['裴杞', '陈政', '栖一', '叶法善', '郑嵎', '无可', '薛昭纬', '徐安贞', '李中', '张嘉贞']
# ['郑嵎', '无可', '薛昭纬', '樊宗师', '薛据', '张嘉贞', '李憕', '陈政', '徐安贞', '李中']
# ['李祎', '翁绶', '薛曜', '王起', '姚系', '万齐融', '武平一', '法照', '陆禹臣', '长孙正隐']
# ['乔琳', '裴耀卿', '魏徵', '陆贽', '陈元光', '裴淑', '张元正', '裴漼', '薛宜僚', '东方虬']
# ['贺兰进明', '祝元膺', '韦皋', '常衮', '王邵', '钱珝', '王绰', '段文昌', '奚贾', '裴潾']
# ['裴贽', '卢延让', '韩湘', '许棠', '敬括', '宋璟', '陈叔达', '裴休', '王纬', '林琨']
# ['张柬之', '张楚金', '钱俶', '崔峒', '裴谞', '郑锡', '邓肃', '张立本女', '李林甫', '侯道华']
# ['薛元超', '王初', '辅国将军', '吴商浩', '孙顾', '裴度', '邓陟', '温宪', '胡证', '唐求']
# ['殷遥', '卢象', '郭周藩', '孙思邈', '李花开', '狄焕', '庞蕴', '怀素', '王播', '张鷟']
# ['张南史', '裴说', '唐彦谦', '裴守真', '窦常', '长孙无忌', '李景让', '裴諴', '贾曾', '裴皞']
# ['李清', '关盼盼', '任翻', '刘言史', '德宗宫人', '巴陵馆鬼', '栖白', '步非烟', '寇坦', '骊山游人']
# ['李爱山', '李节度姬', '李景良', '李君何', '刘洞', '窦夫人', '祖士衡', '吕价', '崔希范', '龚诩']
# ['朱延', '刘琏', '郑浣', '李安期', '释圆', '阎修龄', '纥干讽', '朱翊钧', '罗肃', '杨元亨']
# ['安邑坊女', '白履忠', '白衫举子', '白珽', '白元鉴', '百保', '宝历宫人', '鲍景宣', '本寂', '本净']
# ['毕慧', '辨正', '卜天寿', '蔡江琳', '蔡昆', '蔡押衙', '曹戵', '曹荃', '曹生', '曹文姬']
# ['柴夔', '长孙翱', '长孙氏', '长孙铸', '长屋', '常浩', '常沂', '沉佺期', '陈丙', '陈乘']
# ['陈德诚', '陈甫', '陈季', '陈嘉言', '陈谏', '陈九流', '陈贶', '陈闰', '陈述', '陈素风']
# ['陈蜕', '陈嶰', '陈秀才', '陈义', '陈咏', '陈元裕', '成辅端', '程洛宾', '澄观', '褚朝阳']
# ['褚琇', '慈和', '次休', '崔词', '崔亘', '崔公达', '崔公信', '崔公佐客', '崔恭', '崔光笏']
# ['崔珪', '崔惠童', '崔季卿', '崔建', '崔江', '崔觐', '崔立之', '崔璐', '崔敏童', '崔谟']
# ['崔璞', '崔岐', '崔翘', '崔全素', '崔若砺', '崔素娥', '崔希逸', '崔行检', '崔玄亮', '崔玄童']
# ['崔玄真', '崔膺', '崔载华', '崔知贤', '崔幢', '大颠', '大闲', '大义', '戴寥', '戴司颜']
# ['戴偃', '道慈', '道彦', '德诚', '丁儒', '董思恭', '豆卢复', '窦昉', '窦弘余', '窦希玠']
# ['独孤实', '杜寂', '杜诵', '杜伟', '杜奕', '段倚', '法藏', '法达', '法轮', '法宣']
# ['樊忱', '樊夫人', '樊寔', '樊铸', '繁知一', '范氏子', '范液', '范元凯', '范酂', '方式济']
# ['方愚', '方棫', '房旭', '房元阳', '封抱一', '封彦卿', '冯待征', '冯道幕客', '冯戡', '奉蚌']
# ['符蒙', '复礼', '傅温', '高傪', '高鹤林', '高瑾', '高辇', '高球', '高衢', '高若拙']
# ['高绍', '高湘', '高元矩', '高元裕', '高拯', '戈牢', '哥舒翰', '葛氏女', '公孙杲', '顾朝阳']
# ['顾伟', '顾效古', '顾甄远', '管雄甫', '归仁', '郭翰', '郭夔', '郭利贞', '郭良', '郭良骥']
# ['郭绍兰', '郭慎微', '郭虚己', '郭遵', '海顺', '海印', '韩察', '韩垂', '韩定辞', '韩浚']
# ['韩倩', '韩泰', '韩襄客', '韩彦古', '韩宗', '韩宗恕', '浩虚舟', '何昌龄', '何坚', '何涓']
# ['何鸾', '何频瑜', '何千里', '何儒亮', '何元上', '何兆', '贺遂亮', '红绡妓', '杜昆吾', '杜鸿渐']
# ['洪州将军', '鸿渐', '侯氏', '侯休祥', '胡伯崇', '胡杲', '胡浩然', '胡嘉鄢', '胡权', '胡雄']
# ['崔致远', '胡元龟', '怀楚', '怀浚', '怀浦', '怀信', '怀玉', '桓颙', '幻梦', '皇甫斌']
# ['皇甫澈', '皇甫曙', '黄幡绰', '黄可', '黄麟', '黄山隐', '黄子野', '慧藏', '慧超', '慧忠']
# ['浑惟明', '霍总', '季方', '季广琛', '冀金', '贾邕', '鉴空', '蒋肱', '蒋钧', '蒋密']
# ['蒋氏', '蒋挺', '蒋偕', '解叔禄', '金厚载', '金立之', '金云卿', '荆冬倩', '荆人', '景池']
# ['净显', '久则', '剧燕', '康珽', '康翊仁', '柯崇', '空海', '来鹏', '郎馀令', '乐仲卿']
# ['冷朝阳', '李翱', '李宾', '李伯良', '李伯鱼', '李搏', '李昌邺', '李承之', '李澄之', '李崇嗣']
# ['李从远', '李琮', '李谔', '李范', '李方敬', '李瓘', '李浩', '李合', '李何', '李弘茂']
# ['李季何', '李季华', '李家明', '李兼', '李建枢', '李节', '李京', '李景', '李敬伯', '李敬彝']
# ['李君房', '李溟', '李滂', '李朋', '李平', '李潜', '李日新', '李日知', '李荣', '李荣树']
# ['李如璧', '李韶', '李士元', '李侍御', '李收', '李竦', '李损之', '李太玄', '李潭', '李涛']
# ['李体仁', '李皋', '李景遂', '李诵', '李廷璧', '李蔚', '李遐周', '李翔', '李行敏', '李夐']
# ['李休烈', '李许', '李旭', '李岩', '李彦和', '李彦暐', '李尧夫', '李应', '李屿', '李羽']
# ['李郁', '李元操', '李章武', '李直方', '李质', '李挚', '李骘', '李子昂', '吏部选人', '利涉']
# ['廉氏', '良人', '良乂', '梁德裕', '梁洽', '梁去惑', '梁涉', '梁献', '梁铉', '梁藻']
# ['梁知微', '廖有方', '林楚才', '林逢', '林氏', '林无隐', '林晕', '林蕴', '临川小吏', '灵默']
# ['灵业', '灵准', '泠然', '刘伯翁', '刘长川', '刘道昌', '刘蕃', '刘复', '刘皋', '刘耕']
# ['刘谷', '刘郇伯', '刘晃', '刘敬之', '刘暌', '刘鲁风', '刘璐', '刘猛', '刘锜', '刘慎虚']
# ['刘师服', '刘淑柔', '刘淑颐', '刘畋', '刘望', '刘威', '刘象', '刘行敏', '刘炎', '刘瑶']
# ['刘友贤', '刘元济', '刘媛', '刘真', '刘舟', '柳道伦', '柳登', '柳珪', '柳明献', '柳曾']
# ['楼颖', '卢并', '卢拱', '卢茂钦', '卢骈', '卢频', '卢求', '卢尚卿', '卢尚书', '卢嗣立']
# ['卢嗣业', '卢条', '卢文弨', '卢献卿', '卢休', '卢秀才', '卢言', '卢邺', '卢溵', '卢邕']
# ['卢元辅', '卢载', '卢真', '卢子发', '鲁收', '陆瀍', '陆复礼', '陆亘', '陆海', '陆翚']
# ['陆善经', '陆侍御', '陆质', '路半千', '路黄中', '吕锦文', '吕牧', '吕群', '吕太一', '吕宗健']
# ['论惟明', '罗公远', '罗泰', '马吉甫', '马冉', '马云奇', '马致恭', '马总', '毛炳', '毛涣']
# ['毛明素', '孟不疑', '孟光', '孟球', '孟氏', '孟翔', '孟婴', '米都知', '米岭和尚', '缪岛云']
# ['牛丛', '牛凤及', '牛徵', '欧阳瑾', '潘纯', '潘天锡', '潘咸', '潘雍', '庞季子', '裴达']
# ['裴丹', '裴翻', '裴航', '裴交泰', '裴景福', '裴虔余', '裴思谦', '裴通', '裴翛然', '裴玄智']
# ['裴延龄', '彭蟾', '彭城', '皮光业', '朴昂', '齐安和尚', '齐光乂', '齐推', '綦毋诚', '契盈']
# ['钱徽', '乔氏', '乔舜', '卿云', '清观', '清江', '清尚', '清闲', '清远居士', '屈同仙']
# ['去奢', '全济时', '权龙襄', '权审', '仁俭', '任玠', '任氏', '任涛', '荣九思', '如满']
# ['邵清甫', '邵士彦', '邵真', '绍伯', '申堂构', '神颖', '神赞', '沈回', '沈宁', '沈鹏']
# ['沈宇', '沈祖仙', '慎氏', '师鼐', '石贯', '石文德', '石严', '石殷士', '史昂', '史凤']
# ['李幼卿', '谢勮', '吕岩', '卢藏用', '孙郃', '卫象', '宋若华', '幻梦', '项斯', '沈颜']
# ['温宪', '崔居俭', '莫宣卿', '庄南杰', '丁元和', '郑蜀宾', '岑参', '卢宗回', '张锡', '王勃']
# ['郑世翼', '薛涛', '含曦', '钟蒨', '李贤', '长孙无忌', '邓陟', '符蒙', '姜皎', '喻坦之']
# ['裴航', '李从善', '泠然', '裴大章', '李伯良', '阎济美', '乔侃', '李如璧', '沈东美', '文秀']
# ['张籍', '钱镠', '苏拯', '祖咏', '景云', '杨续', '吕敞', '黄颇', '郑綮', '李廷璧']
# ['赵徵明', '孙思邈', '刘迥', '裴通', '刘师服', '李昌符', '张籍', '梁宝', '羊滔', '崔立言']
# ['蒋防', '李安期', '李胄', '王炎午', '郑述诚', '法轮', '郑丹', '段成式', '李潭', '白珽']
# ['崔惠童', '包贺', '贺朝', '舒元舆', '杜頠', '常理', '解叔禄', '卢尚卿', '卢并', '高若拙']
# ['翁承赞', '阎修龄', '林璠', '卫象', '湘驿女子', '李峤', '李敬伯', '柳公权', '长孙铸', '冯戡']
# ['包贺', '李甘', '法藏', '韦镒', '吴武陵', '黄旛绰', '刘崇龟', '储光羲', '伶人', '敬括']
# ['李章', '李爱山', '李讷', '陈义', '申堂构', '南巨川', '王晙', '徐介', '魏知古', '狄归昌']
# ['王福娘', '韩察', '卢士衡', '杨元亨', '张随', '卢邺', '郑嵎', '易思', '郑符', '窦牟']
# ['吕敞', '王毂', '王延彬', '薛元超', '黄山隐', '李纾', '崔全素', '孟简', '宋之问', '李宣远']
# ['李日新', '韦元旦', '苏源明', '颜舒', '李乂', '崔恭', '骆宾王', '张文规', '扈载', '卢求']
# ['赵牧', '陈德诚', '崔亘', '浑惟明', '谭峭', '刘望', '宋若华', '周庠', '杨敬述', '李迥秀']
# ['崔全素', '寇坦', '朱湾', '夏侯审', '王湾', '李适', '曹汾', '杨贲', '杜常', '赵防']
# ['步非烟', '方式济', '李君何', '法达', '房旭', '丁泽', '萧妃', '孙頠', '贺遂涉', '马戴']
# ['鱼又玄', '王沈', '王炎午', '崔琮', '张彪', '吴秘', '海印', '窦叔向', '尉佗', '包佶']
# ['梁藻', '崔禹锡', '苏晋', '崔铉', '谢勮', '韦元甫', '徐侃', '顾云', '萧意', '吴越人']
# ['沈宇', '陶雍', '卢条', '刘景复', '徐锴', '陆翚', '刘升', '崔禹锡', '皇甫镛', '怀浦']
# ['白居易', '李皋', '柳道伦', '姚嵘', '如满', '姚伦', '王绩', '卢宗回', '秦韬玉', '滕迈']
# ['王韫秀', '何元上', '李屿', '王仲舒', '孙棨', '方干', '韦渠牟', '魏征', '裴翛然', '杜淹']
# ['杨炯', '许敬宗', '丘丹', '刘昚虚', '颜仁郁', '崔玄亮', '陈义', '王昌龄', '王炎午', '李合']
# ['权龙襄', '刘崇鲁', '李蔚', '于兴宗', '杜正伦', '陆善经', '陆贞洞', '刘景复', '许棠', '贺敱']
# ['卢秀才', '元万顷', '胡杲', '高元矩', '吕牧', '高铢', '卢邺', '徐玄之', '陆畅', '严识玄']
# ['姚嵘', '李渤', '薛克构', '赵光远', '赵良器', '张为', '李士元', '张顶', '廖融', '李幼卿']
# ['封行高', '蒋吉', '康翊仁', '聂夷中', '李旭', '韦蟾', '刘祎之', '季方', '张昔', '张松龄']
# ['独孤实', '冯道之', '安锜', '薛昭纬', '王纬', '李伯良', '黄颇', '袁恕己', '裴休', '崔词']
# ['张若虚', '繁知一', '李渤', '秦韬玉', '姜皎', '韦瓘', '赵嘏', '何元上', '孙樵', '陈羽']
# ['杨凝式', '郭翰', '刘友贤', '杨凭', '韦应物', '灵默', '李徵古', '义净', '敬括', '解叔禄']
# ['皇甫松', '郭慎微', '窦梁宾', '谢良辅', '胡传美', '畅诸', '孙佺', '省吏', '宋若宪', '詹琲']
# ['朱泽', '陆畅', '胡传美', '高峤', '白元鉴', '沈传师', '闾丘晓', '贾岛', '韦元旦', '季广琛']
# ['孙子多', '宇文鼎', '卢茂钦', '朱休', '李程', '郑史', '张柬之', '韦济', '大闲', '李显']
# ['李遵勖', '李士元', '范传质', '李宗闵', '窦冀', '临川小吏', '李岩', '庾抱', '郑孺华', '薛据']
# ['冯伉', '唐求', '薛宜僚', '林披', '钟蒨', '裴铏', '杨敬之', '卢绛', '李兼', '黄幡绰']
# ['崔知贤', '护国', '邓洵美', '荆人', '苏郁', '栖蟾', '卢文纪', '许康佐', '杨奇鲲', '马乂']
# ['陈子昂', '章碣', '朱湾', '邓倚', '李肱', '卢条', '郑谷', '任华', '安鸿渐', '曹文姬']
# ['吕敞', '高元矩', '李谅', '杨损', '卢尚书', '毛涣', '罗让', '童翰卿', '范元凯', '薛琼']
# ['皇甫斌', '胥偃', '乔舜', '夏鸿', '刘畋', '缪氏子', '长屋', '白珽', '黎逢', '吴筠']
# ['方棫', '谢良辅', '李缟', '李公佐仆', '元础', '陆长源', '卢殷', '朴昂', '卢征', '李廷璧']
# ['李隆基', '陈陶', '陈元光', '高瑾', '梁安世', '韦表微', '金地藏', '储光羲', '魏奉古', '高元裕']
# ['黎逢', '李景伯', '胡嘉鄢', '南溟夫人', '翁洮', '白珽', '唐远悊', '武翊黄', '方干', '李乂']
# ['王福娘', '权龙褒', '卢藏用', '于良史', '窦梁宾', '裴休', '王瓒', '商则', '李适之', '颜舒']
# ['封孟绅', '长孙氏', '张碧', '钱俶', '李亨', '任涛', '高辇', '蔡江琳', '慧宣', '李隆基']
# ['刘威', '纪唐夫', '豆卢回', '辨才', '薛奇童', '王初', '安锜', '何频瑜', '苏味道', '李景俭']
# ['孙顾', '赵虚舟', '李真', '李瓘', '胡传美', '徐铉', '李元操', '卢载', '李衢', '崔翘']
# ['刘乙', '王炎午', '李季华', '张南史', '元希声', '舞柘枝女', '刘山甫', '孙樵', '陈琡', '唐求']
# ['无闷', '王毂', '杨师道', '郑谷', '唐求', '妙女', '刘济', '孟翔', '窦威', '许宣平']
# ['朱子真', '马逢', '杨志坚', '李公佐仆', '蒯希逸', '怀信', '房旭', '卢殷', '陈至', '卢纶']
# ['梁藻', '仲子陵', '王烈', '皇甫斌', '王適', '韦嗣立', '陈希烈', '孙佺', '解琬', '王鲁复']
# ['王丘', '姜皎', '权审', '袁高', '荆人', '辛弘智', '薛元超', '陆海', '裴通', '周弘亮']
# ['拾得', '阎敬爱', '卢尚卿', '谈戭', '窦昉', '童翰卿', '崔澹', '李纾', '荆冬倩', '贾弇']
# ['王湾', '朱使欣', '朱宿', '杨洵美', '朱湾', '李沛', '郭郧', '盛小丛', '杜鸿渐', '郑昉']
# ['韦夏卿', '沙正卿', '程弥纶', '吕渭', '崔希范', '论惟明', '卢顺之', '窦昉', '严郾', '浩虚舟']
# ['袁郊', '黄损', '崔橹', '西鄙人', '吕温', '高正臣', '陈季', '李如璧', '林楚翘', '曹唐']
# ['翁承赞', '赵良器', '李缜', '张希复', '道会', '查文徽', '常雅', '裴翛然', '王绩', '王正己']
# ['牛凤及', '李岩', '景云', '陈至', '常非月', '解叔禄', '丘悦', '徐介', '韩彦古', '路应']
# ['张固', '袁皓', '崔少玄', '高拯', '胡杲', '李昼', '陆龟蒙', '李縠', '潘佑', '赵谦光']
# ['卢群', '白行简', '陈通方', '林滋', '崔致远', '吴商浩', '闾丘晓', '李太玄', '冯涯', '林楚才']
# ['崔词', '梁琼', '张继', '弓嗣初', '韩仪', '丁谓', '郭受', '崔护', '陈政', '陆弘休']
# ['王贞白', '王储', '刘知几', '张子容', '石惠泰', '张曙', '郑常', '李渤', '张锡', '豆卢回']
# ['康有为', '刘太真', '卢从愿', '张顶', '刘师服', '清江', '柳浑', '胡令能', '裴交泰', '李方敬']
# ['常非月', '姚系', '费唐臣', '王諲', '崔公佐客', '羊昭业', '苏晋', '李从善', '高绍', '毛明素']
# ['孟昶', '杜甫', '谭用之', '闾丘均', '许碏', '德诚', '刘崇龟', '权龙褒', '姚嵘', '李章武']
# ['来济', '萧嵩', '陆扆', '李朋', '令狐楚', '陈九流', '李正辞', '关盼盼', '郎士元', '冯戡']
# ['释宝月', '窦洵直', '李逢吉', '子兰', '严识玄', '崔惠童', '范朝', '秦韬玉', '公乘亿', '柳公权']
# ['任华', '许棠', '王丘', '舒元舆', '杜之松', '郭元振', '韦庄', '怀素', '阎德隐', '窦蒙']
# ['尉迟汾', '刘乙', '杨昭俭', '德诚', '员半千', '卢贞', '丁元和', '郑嵎', '李克恭', '僧鸾']
# ['杨损', '范尧佐', '张绍', '郭元振', '蔡希周', '清观', '毕慧', '贺知章', '陆肱', '李贤']
# ['李平', '杨牢', '席夔', '卢尚书', '李恒', '韦瓘', '陶雍', '赵惠宗', '顾云', '杨知至']
# ['杨齐哲', '郭翰', '徐灵府', '萧意', '郭利贞', '张松龄', '周匡物', '刘廓', '李夔', '高绍']
# ['韩思彦', '卜天寿', '乔氏', '长屋', '徐光溥', '卢邕', '道会', '高退之', '裴达', '刘虚白']
# ['卢肇', '丰干', '李绅', '仲子陵', '王建', '柳泌', '法藏', '良乂', '秦韬玉', '钱起']
# ['卢载', '耽章', '卢嗣立', '崔郾', '张谔', '张垍', '陈京', '司空图', '杜易简', '周濆']
# ['裴谞', '裴迪', '陈标', '马吉甫', '李祜', '孙頠', '刘言史', '卢照邻', '高退之', '窦蒙']
# ['李侍御', '吕宗健', '姚嵘', '白居易', '鲍景宣', '吴武陵', '胡元龟', '韩仲宣', '黄公绍', '刘蕃']
# ['杜伟', '黄蘖禅师', '孔绍安', '黎逢', '陆禹臣', '钱起', '捧剑仆', '张令问', '刘晃', '许景先']
# ['沈叔安', '田澄', '石抱忠', '李馀', '王琚', '邢象玉', '郑符', '朱湾', '陶翰', '郑辕']
# ['裴交泰', '处默', '羊昭业', '崔立之', '孟彦深', '张仁宝', '张循之', '杜审言', '胡直钧', '萧彧']
# ['皮日休', '严武', '高适', '封行高', '黎逢', '李治', '李行言', '郑絪', '郭正一', '郑颋']
# ['邵士彦', '李嶷', '秦系', '路黄中', '赵蕤', '储嗣宗', '窦巩', '冯著', '孟守', '周渭']
# ['吕渭', '康有为', '陈存', '杨贲', '欧阳玭', '李宣古', '汪遵', '崔敏童', '刘复', '大愚']
# ['管雄甫', '刘皂', '储嗣宗', '庾传素', '顾封人', '崔郾', '郑綮', '朱翊钧', '皇甫斌', '李夐']
# ['孙樵', '李赞华', '胡幽贞', '陶拱', '李赤', '谢偃', '中寤', '王铎', '李彦暐', '颜真卿']
# ['李归唐', '蔡瑰', '陈润', '崔日用', '张文规', '陆海', '苏味道', '崔膺', '李令', '张顶']
# ['卢士政', '释彪', '韦述', '郑俞', '王仲舒', '李康成', '沈仲昌', '王鲁复', '繁知一', '崔萱']
# ['何希尧', '李缜', '徐惠', '王起', '裴士淹', '薛据', '黎瓘', '释泚', '蔡希周', '刘媛']
# ['郑师贞', '张昌宗', '李何', '张嘉贞', '卢群', '吴涵虚', '毛熙震', '李从善', '封行高', '安鸿渐']
# ['雍陶', '张怀庆', '韩仲宣', '姚合', '陈祜', '卢溵', '胡直钧', '黄幡绰', '李伉', '冯宿']
# ['富嘉谟', '李世民', '窦参', '乔备', '常楚老', '刘谷', '樊晃', '李祎', '崔液', '孟简']
# ['羊士谔', '刘沧', '伊用昌', '高拯', '郑巢', '郭良骥', '西鄙人', '陆景初', '邵清甫', '沈彬']
# ['钱珝', '李朋', '李质', '徐月英', '牛凤及', '魏兼恕', '萧翼', '潘图', '罗珦', '樊忱']
# ['狄焕', '卢携', '毛炳', '宋璟', '殷文圭', '可止', '朱昼', '裴潾', '栖白', '郑颋']
# ['解叔禄', '宗楚客', '彭蟾', '仁俭', '樊忱', '陈叔达', '郑絪', '唐备', '孙偓', '郎士元']
# ['卢从愿', '李崇嗣', '权龙褒', '吴子来', '李世民', '王適', '卜天寿', '范酂', '阎修龄', '潘孟阳']
# ['次休', '李兼', '崔居俭', '刘暌', '元友直', '杜之松', '王沈', '喻凫', '上官昭容', '冯道幕客']
# ['蔡江琳', '彭晓', '李虞仲', '杜寂', '朱庆馀', '张蠙', '焦郁', '毛文锡', '妙女', '韩翃']
# ['刘友贤', '全济时', '黄子野', '范传质', '徐浩', '韦抗', '李浩弼', '卢栯', '长孙铸', '包贺']
# ['毛涣', '崔国辅', '李都', '李正封', '张均', '张浑', '甘洽', '冷朝光', '韦渠牟', '崔日用']
# ['陈元裕', '韩湘', '王质', '萧楚材', '马戴', '陆侍御', '栖一', '杜伟', '刘太冲', '王苏苏']
# ['崔岐', '沈徽', '季方', '王表', '黄麟', '万齐融', '郎士元', '郭遵', '耿时举', '庞蕴']
# ['郭震', '海印', '韩倩', '郑缙', '宋若宪', '沈千运', '张窈窕', '张南容', '王正己', '神赞']
# ['于武陵', '王諲', '路洵美', '李夷简', '吕敞', '阎防', '郑嵎', '何希尧', '崔备', '黄崇嘏']
# ['于季子', '张绍', '郭翰', '封敖', '张嘉贞', '虞刚简', '马怀素', '章八元', '聂夷中', '布燮']
# ['李谔', '黎逢', '郑光业', '刘淑柔', '刘璐', '朱延', '胡证', '刘斌', '段怀然', '杨巨源']
# ['李行言', '恒超', '褚亮', '陆禹臣', '马令', '常非月', '李宾', '陶岘', '李吉甫', '李怀远']
# ['李朋', '乾康', '李穆', '伍乔', '权龙襄', '章玄同', '常建', '贾谟', '善生', '郑南金']
# ['柳公绰', '崔融', '胡元范', '刘绮庄', '樊忱', '郑辕', '黎逢', '庾光先', '喻坦之', '上官仪']
# ['卢求', '金云卿', '刘沧', '定志', '周濆', '郭正一', '独孤申叔', '张荐', '廖凝', '陈峤']
# ['赵惠宗', '石抱忠', '刘师服', '阎防', '沈叔安', '王韫秀', '赵光逢', '李义府', '蔡希寂', '雍陶']
# ['陈甫', '廖匡图', '吴融', '杨续', '王德真', '姚向', '封抱一', '石殷士', '孟氏', '罗让']

# %%
len(poems)
