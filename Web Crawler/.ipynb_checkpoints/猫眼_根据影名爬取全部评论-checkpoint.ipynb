# %% [markdown]
# ### 获取全部评论

# %%
# coding: utf-8
import re 
import pandas as pd
import requests
import random
import json
from urllib import parse
from urllib import request
import time
from datetime import datetime
from datetime import timedelta
header={
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36',
    'Connection':'keep-alive'
}
cookies = '__mta=147569288.1539613293789.1539613310187.1539616722700.3; v=3; \
        _lxsdk_cuid=166781a789ec8-0139751cb2ee6e-8383268-144000-166781a789fc8; \
        __mta=147569288.1539613293789.1539613293789.1539613310187.2; uuid_n_v=v1; \
        iuuid=9AF20AC0D08D11E89D508D0D63C93F71D10FE6A2B71B406D800371E2CD9160FE; webp=true; ci=96%2C%E6%B5%8E%E5%8D%97; \
        _lxsdk=9AF20AC0D08D11E89D508D0D63C93F71D10FE6A2B71B406D800371E2CD9160FE; _lxsdk_s=166784ecee0-b1a-f0b-22%7C%7C2'
cookie = {}
for line in cookies.split(';'):
    name, value = cookies.strip().split('=', 1)
    cookie[name] = value

# %%
def get_id_by_name(name):
    url = 'http://maoyan.com/query?'
    dict1 ={'kw': name}
    url_data = parse.urlencode(dict1) #unlencode()将字典{k1:v1,k2:v2}转化为k1=v1&k2=v2
    html = requests.get(url=url+url_data, cookies=cookie,headers=header).content.decode('utf-8')
    movie_item = re.findall(r'data-val=\"{movieid:(.*?)}">', html)
    if len(movie_item)==0:
        return -1
    else:
        return movie_item[0]

# %%
def get_release_time_by_name(name):
    id = get_id_by_name(name)
    if id == -1:
        return None
    else:
        url = 'http://maoyan.com/films/'+get_id_by_name(name)
#         print(url)
        html = requests.get(url=url, cookies=cookie,headers=header).content.decode('utf-8')
        s = r'<li class=\"ellipsis\">(.*?)映<\/li>'
        release_time = re.findall(s, html)
        return release_time[0][0:10]#只截取时间 如 2018-09-30

# %%
# def get_comments_all(name):
#     comments = pd.DataFrame(columns=['data','score','city','comment','nick','gender'])
#     start_time = datetime.now().strftime('%Y-%m-%d %H:%M:%S')  # 获取当前时间，从当前时间向前获取
#     release_time = str(get_release_time_by_name(name))
#     end_time =  release_time+' 00:00:00'
#     count=0
#     comments.to_csv('all_'+name+'.csv',index=False,encoding="utf_8_sig")
# #     for i in range(0,2):
#     while start_time > end_time:  
#         try:
#             time.sleep(0.2)
            
#             url = 'http://m.maoyan.com/mmdb/comments/movie/'+get_id_by_name(name)+'.json?_v_=yes&offset=0&startTime=' + start_time.replace(' ', '%20')
#             print(str(count)+"  "+url)
#             count = count+1
#             html = requests.get(url=url, cookies=cookie,headers=header).content.decode('utf-8')
#             data = json.loads(html)['cmts']
           
#             start_time = data[len(data)-1]['startTime']  # 获得末尾评论的时间
#             start_time = datetime.strptime(start_time, '%Y-%m-%d %H:%M:%S') + timedelta(seconds=-1)  # 转换为datetime类型，减1秒，避免获取到重复数据
#             start_time = datetime.strftime(start_time, '%Y-%m-%d %H:%M:%S')  # 转换为str
 
#             for item in data:
#                 try:
#                     comments = comments.append({'data':item['time'].split(' ')[0],'city':item['cityName'],
#                                                     'score':str(item['score']),'comment':item['content'],
#                                                 'nick':item['nick'],'gender':item['gender']},
#                                                    ignore_index=True)
#                 except:
#                     comments = comments.append({'data':item['time'].split(' ')[0],'city':item['cityName'],
#                                                     'score':str(item['score']),'comment':item['content'],
#                                                 'nick':item['nick'],'gender':0},
#                                                    ignore_index=True)
#             comments.to_csv('all_'+name+'.csv',index=False,mode='a', header=False,encoding="utf_8_sig")
#             comments.drop(comments.index,inplace=True)#清空comments   
                    
#         except Exception as e:
#             time.sleep(0.5)
#             print(e)
#             continue

# %%
def get_comments_all(name):
    comments = pd.DataFrame(columns=['data','score','city','comment','nick','gender'])
    start_time = datetime.now().strftime('%Y-%m-%d %H:%M:%S')  # 获取当前时间，从当前时间向前获取
    release_time = str(get_release_time_by_name(name))
    end_time =  release_time+' 00:00:00'
    comments.to_csv('all_'+name+'.csv',index=False,encoding="utf_8_sig")
    count=0
    pages =15
    
    while pages ==15:  
        try:
#             time.sleep(0.2)
            
            url = 'http://m.maoyan.com/mmdb/comments/movie/'+get_id_by_name(name)+'.json?_v_=yes&offset=0&startTime=' + start_time.replace(' ', '%20')
            print(str(count)+"  "+url)
            count = count+1
            html = requests.get(url=url, cookies=cookie,headers=header).content.decode('utf-8')
            data = json.loads(html)['cmts']
            pages=len(data)

            for item in data:
                if item.get('cityName')==None or item.get('time')==None or item.get('score')==None or item.get('content')==None or item.get('nick')==None:
                    print("jump")
                else:  
                    try:
                        comments = comments.append({'data':item['time'].split(' ')[0],'city':item['cityName'],
                                                        'score':str(item['score']),'comment':item['content'],
                                                    'nick':item['nick'],'gender':item['gender']},
                                                       ignore_index=True)
                    except:
                        comments = comments.append({'data':item['time'].split(' ')[0],'city':item['cityName'],
                                                        'score':str(item['score']),'comment':item['content'],
                                                    'nick':item['nick'],'gender':0},
                                                       ignore_index=True)
            comments.to_csv('all_'+name+'.csv',index=False,mode='a', header=False,encoding="utf_8_sig")
            
            start_time = data[14]['startTime']  # 获得末尾评论的时间
            start_time = datetime.strptime(start_time, '%Y-%m-%d %H:%M:%S') + timedelta(seconds=-1)  # 转换为datetime类型，减1秒，避免获取到重复数据
            start_time = datetime.strftime(start_time, '%Y-%m-%d %H:%M:%S')  # 转换为str
            
            comments.drop(comments.index,inplace=True)#清空comments   

        except Exception as e:
            time.sleep(0.5)
            print(e)
            continue

# %%
def get_comments_continue(name,start_time):
    comments = pd.DataFrame(columns=['data','score','city','comment','nick','gender'])
    release_time = str(get_release_time_by_name(name))
    end_time =  release_time+' 00:00:00'
    count=0
    pages =15
    
    url = 'http://m.maoyan.com/mmdb/comments/movie/'+get_id_by_name(name)+'.json?_v_=yes&offset=0&startTime=' + start_time
    html = requests.get(url=url, cookies=cookie,headers=header).content.decode('utf-8')
    data = json.loads(html)['cmts']
    pages=len(data)
    start_time = data[14]['startTime']  # 获得末尾评论的时间
    start_time = datetime.strptime(start_time, '%Y-%m-%d %H:%M:%S') + timedelta(seconds=-1)  # 转换为datetime类型，减1秒，避免获取到重复数据
    start_time = datetime.strftime(start_time, '%Y-%m-%d %H:%M:%S')  # 转换为str
    
    while pages ==15:  
        try:
            time.sleep(0.2)
            
            url = 'http://m.maoyan.com/mmdb/comments/movie/'+get_id_by_name(name)+'.json?_v_=yes&offset=0&startTime=' + start_time.replace(' ', '%20')
            print(str(count)+"  "+url)
            count = count+1
            html = requests.get(url=url, cookies=cookie,headers=header).content.decode('utf-8')
            data = json.loads(html)['cmts']
            pages=len(data)

            for item in data:
                if item.get('cityName')==None or item.get('time')==None or item.get('score')==None or item.get('content')==None or item.get('nick')==None:
                    print("jump")
                else:  
                    try:
                        comments = comments.append({'data':item['time'].split(' ')[0],'city':item['cityName'],
                                                        'score':str(item['score']),'comment':item['content'],
                                                    'nick':item['nick'],'gender':item['gender']},
                                                       ignore_index=True)
                    except:
                        comments = comments.append({'data':item['time'].split(' ')[0],'city':item['cityName'],
                                                        'score':str(item['score']),'comment':item['content'],
                                                    'nick':item['nick'],'gender':0},
                                                       ignore_index=True)
            comments.to_csv('all_'+name+'.csv',index=False,mode='a', header=False,encoding="utf_8_sig")
            
            start_time = data[14]['startTime']  # 获得末尾评论的时间
            start_time = datetime.strptime(start_time, '%Y-%m-%d %H:%M:%S') + timedelta(seconds=-1)  # 转换为datetime类型，减1秒，避免获取到重复数据
            start_time = datetime.strftime(start_time, '%Y-%m-%d %H:%M:%S')  # 转换为str
            comments.drop(comments.index,inplace=True)#清空comments   

        except Exception as e:
            time.sleep(0.5)
            print(e)
            continue

# %%
# get_comments_all("无双")

# %%
# get_comments_all("李茶的姑妈") #3718

# %%
# get_comments_all("影") #3729

# %%
get_comments_all("找到你") #

# %%
get_comments_all("胖子行动队")

# %%
# get_comments_all("嘻哈英熊")

# %%
# get_comments_all("新灰姑娘")

# %%
# get_comments_all("阿凡提之奇缘历险")

# %%
get_comments_all("夏洛特烦恼") #70w

# %%
get_comments_all("驴得水") #6w
# Out:
# 0  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2018-10-19%2015:19:47
# 1  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2018-09-03%2017:15:57
# 2  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2018-07-29%2013:46:47
# 3  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2018-07-04%2017:24:58
# 4  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2018-05-27%2021:24:51
# 5  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2018-04-22%2017:01:32
# 6  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2018-04-04%2016:39:03
# 7  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2018-03-12%2011:35:38
# 8  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2018-02-22%2022:40:00
# 9  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2018-02-07%2017:55:02
# 10  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2018-01-20%2012:35:42
# 11  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2018-01-05%2009:35:45
# 12  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-12-21%2020:28:44
# 13  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-11-28%2023:28:20
# 14  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-11-15%2000:20:02
# 15  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-11-02%2016:05:11
# 16  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-10-21%2022:58:51
# 17  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-10-16%2023:34:30
# 18  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-10-12%2020:59:14
# 19  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-10-09%2011:03:04
# 20  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-10-06%2023:18:03
# 21  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-10-04%2012:23:24
# 22  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-10-02%2017:58:08
# 23  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-09-30%2014:40:28
# 24  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-09-27%2017:36:32
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-ca23b882f111> in <module>()
# ----> 1 get_comments_all("驴得水") #6w
#
# <ipython-input-6-49106f302f6f> in get_comments_all(name)
#      15             print(str(count)+"  "+url)
#      16             count = count+1
# ---> 17             html = requests.get(url=url, cookies=cookie,headers=header).content.decode('utf-8')
#      18             data = json.loads(html)['cmts']
#      19             pages=len(data)
#
# D:\Anaconda\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# D:\Anaconda\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# D:\Anaconda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# D:\Anaconda\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# D:\Anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# D:\Anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# D:\Anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# D:\Anaconda\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# D:\Anaconda\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# D:\Anaconda\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# D:\Anaconda\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# get_comments_all("羞羞的铁拳")

# %%
# get_comments_all("西虹市首富") #25943

# %%
get_comments_continue("驴得水",'2017-09-01%2021:23:22')
# Out:
# 0  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-08-27%2012:15:00
# 1  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-08-22%2014:01:53
# 2  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-08-19%2009:26:24
# 3  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-08-14%2019:40:26
# 4  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-08-12%2002:58:36
# 5  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-08-09%2017:34:31
# 6  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-08-08%2009:28:00
# 7  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-08-06%2022:24:45
# 8  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-08-06%2010:20:21
# 9  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-08-05%2011:36:57
# 10  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-08-04%2019:35:02
# 11  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-08-03%2011:19:00
# 12  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-08-02%2007:28:58
# 13  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-07-31%2020:29:22
# 14  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-07-30%2016:55:35
# 15  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-07-29%2019:11:39
# 16  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-07-28%2015:06:57
# 17  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-07-27%2010:36:27
# 18  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-07-25%2015:45:45
# 19  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-07-23%2017:37:54
# 20  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-07-22%2012:37:55
# 21  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-07-20%2016:04:23
# 22  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-07-19%2010:30:43
# 23  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-07-17%2018:11:18
# 24  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-07-16%2021:39:07
# 25  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-07-16%2012:43:02
# 26  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-07-15%2015:29:09
# 27  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-07-13%2017:12:00
# 28  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-07-12%2011:55:32
# 29  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-07-10%2019:22:53
# 30  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-07-09%2015:43:41
# 31  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-07-08%2012:44:25
# 32  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-07-07%2018:11:06
# 33  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-07-06%2011:02:44
# 34  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-07-05%2009:34:52
# 35  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-07-04%2011:24:43
# 36  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-07-03%2007:04:50
# 37  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-07-01%2020:10:56
# 38  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-06-30%2015:48:24
# 39  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-06-29%2015:40:25
# 40  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-06-28%2016:27:09
# 41  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-06-27%2016:03:23
# 42  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-06-26%2001:36:12
# 43  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-06-25%2010:05:25
# 44  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-06-24%2011:58:15
# 45  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-06-23%2011:17:29
# 46  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-06-21%2022:03:21
# 47  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-06-20%2015:29:24
# 48  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-06-19%2009:57:24
# 49  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-06-17%2022:05:05
# 50  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-06-16%2016:34:01
# 51  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-06-14%2018:04:46
# 52  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-06-13%2018:17:51
# 53  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-06-12%2016:14:16
# 54  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-06-11%2018:34:24
# 55  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-06-10%2021:51:34
# 56  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-06-10%2000:59:40
# 57  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-06-08%2012:31:03
# 58  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-06-07%2011:35:37
# 59  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-06-06%2012:35:23
# 60  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-06-05%2011:19:01
# 61  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-06-04%2010:51:27
# 62  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-06-03%2017:40:39
# 63  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-06-03%2003:40:04
# 64  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-06-02%2001:32:38
# 65  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-06-01%2014:20:04
# 66  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-05-31%2020:51:26
# 67  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-05-30%2020:29:42
# 68  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-05-29%2023:51:40
# 69  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-05-29%2011:49:18
# 70  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-05-28%2019:05:44
# 71  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-05-27%2017:54:24
# 72  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2017-05
http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2018:09:46
# 3086  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2018:06:05
# 3087  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2018:02:49
# 3088  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2018:00:22
# 3089  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2017:58:20
# 3090  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2017:54:38
# 3091  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2017:52:18
# 3092  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2017:50:01
# 3093  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2017:47:13
# 3094  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2017:43:56
# 3095  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2017:41:11
# 3096  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2017:39:00
# 3097  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2017:36:14
# 3098  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2017:31:26
# 3099  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2017:29:34
# 3100  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2017:27:29
# 3101  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2017:23:43
# 3102  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2017:21:12
# 3103  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2017:18:55
# 3104  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2017:16:06
# 3105  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2017:13:04
# 3106  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2017:09:54
# 3107  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2017:08:02
# 3108  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2017:04:57
# 3109  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2017:01:48
# 3110  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2016:58:27
# 3111  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2016:55:24
# 3112  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2016:52:04
# 3113  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2016:48:59
# 3114  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2016:46:22
# 3115  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2016:43:36
# 3116  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2016:41:34
# 3117  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2016:39:09
# 3118  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2016:34:37
# 3119  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2016:31:54
# 3120  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2016:30:28
# 3121  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2016:26:56
# 3122  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2016:22:57
# 3123  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2016:20:07
# 3124  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2016:16:37
# 3125  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2016:13:26
# 3126  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2016:11:33
# 3127  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2016:08:38
# 3128  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2016:06:42
# 3129  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2016:03:42
# 3130  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2016:01:05
# 3131  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2015:59:02
# 3132  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2015:56:22
# 3133  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2015:53:04
# 3134  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2015:49:32
# 3135  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2015:46:13
# 3136  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2015:41:37
# 3137  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2015:39:32
# 3138  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2015:34:12
# 3139  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2015:31:26
# 3140  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2015:26:36
# 3141  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2015:22:38
# 3142  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2015:18:26
# 3143  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2015:15:13
# 3144  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2015:12:31
# 3145  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2015:09:28
# 3146  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2015:04:10
# 3147  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2015:00:17
# 3148  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2014:55:20
# 3149  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2014:49:39
# 3150  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2014:47:15
# 3151  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2014:40:53
# 3152  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2014:35:58
# 3153  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2014:31:27
# 3154  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2014:26:33
# 3155  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2014:21:29
# 3156  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2014:13:19
# 3157  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2014:08:34
# 3158  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2014:05:04
# 3159  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2014:01:12
# 3160  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2013:57:01
# 3161  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2013:51:36
# 3162  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2013:47:00
# 3163  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2013:41:43
# 3164  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2013:38:27
# 3165  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2013:31:42
# 3166  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2013:27:51
# 3167  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2013:22:52
# 3168  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2013:18:18
# 3169  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2013:13:56
# 3170  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2013:07:42
# 3171  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2013:04:03
# 3172  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2013:00:04
# 3173  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2012:56:55
# 3174  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2012:53:45
# 3175  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2012:50:22
# 3176  http://m.maoyan.com/mmdb/comments/movie/410612.json?_v_=yes&offset=0&startTime=2016-10-30%2012:46:00
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-6a9fb1a92047> in <module>()
# ----> 1 get_comments_continue("驴得水",'2017-09-01%2021:23:22')
#
# <ipython-input-7-89083720c0da> in get_comments_continue(name, start_time)
#      21             print(str(count)+"  "+url)
#      22             count = count+1
# ---> 23             html = requests.get(url=url, cookies=cookie,headers=header).content.decode('utf-8')
#      24             data = json.loads(html)['cmts']
#      25             pages=len(data)
#
# D:\Anaconda\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# D:\Anaconda\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# D:\Anaconda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# D:\Anaconda\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# D:\Anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# D:\Anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# D:\Anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# D:\Anaconda\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# D:\Anaconda\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# D:\Anaconda\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# D:\Anaconda\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:
