# %% [markdown]
# ### 获取数据

# %%
# coding: utf-8
import pandas as pd
import requests
import random
import json
import time
header={
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36',
    'Connection':'keep-alive'
}
cookies = '__mta=147569288.1539613293789.1539613310187.1539616722700.3; v=3; \
        _lxsdk_cuid=166781a789ec8-0139751cb2ee6e-8383268-144000-166781a789fc8; \
        __mta=147569288.1539613293789.1539613293789.1539613310187.2; uuid_n_v=v1; \
        iuuid=9AF20AC0D08D11E89D508D0D63C93F71D10FE6A2B71B406D800371E2CD9160FE; webp=true; ci=96%2C%E6%B5%8E%E5%8D%97; \
        _lxsdk=9AF20AC0D08D11E89D508D0D63C93F71D10FE6A2B71B406D800371E2CD9160FE; _lxsdk_s=166784ecee0-b1a-f0b-22%7C%7C2'
cookie = {}
for line in cookies.split(';'):
    name, value = cookies.strip().split('=', 1)
    cookie[name] = value
print(cookie)
# Out:
# {'__mta': '147569288.1539613293789.1539613310187.1539616722700.3; v=3;         _lxsdk_cuid=166781a789ec8-0139751cb2ee6e-8383268-144000-166781a789fc8;         __mta=147569288.1539613293789.1539613293789.1539613310187.2; uuid_n_v=v1;         iuuid=9AF20AC0D08D11E89D508D0D63C93F71D10FE6A2B71B406D800371E2CD9160FE; webp=true; ci=96%2C%E6%B5%8E%E5%8D%97;         _lxsdk=9AF20AC0D08D11E89D508D0D63C93F71D10FE6A2B71B406D800371E2CD9160FE; _lxsdk_s=166784ecee0-b1a-f0b-22%7C%7C2'}

# %%
url = 'http://m.maoyan.com/mmdb/comments/movie/1203437.json?_v_=yes&offset=60'
html = requests.get(url=url, cookies=cookie,headers=header).content.decode('utf-8')

# %%
data = json.loads(html)['cmts']

# %%
print(data[0].get('gender'))
# Out:
# None

# %%
ying = pd.DataFrame(columns=['data','score','city','comment','nick','gender'])
for item in data:
    try:
        ying = ying.append({'data':item['time'].split(' ')[0],'city':item['cityName'],
                                        'score':str(item['score']),'comment':item['content'],'nick':item['nick'],'gender':item['gender']},
                                       ignore_index=True)
    except:
        ying = ying.append({'data':item['time'].split(' ')[0],'city':item['cityName'],
                                        'score':str(item['score']),'comment':item['content'],'nick':item['nick'],'gender':0},
                                       ignore_index=True)
print(ying)
# Out:
#           data score city                                            comment  \
# 0   2018-10-16   3.5   吴江                                       剧情有点弱，水墨画风满分
# 1   2018-10-16     4   长春   好像模拟几十年前日本导演黑泽明的影子武士武田信玄！不过演员演技一流，值得一看，拍摄手法也很有👓
# 2   2018-10-16   2.5   湘潭                                           不好看，剧情拖沓
# 3   2018-10-16     4   青岛                                   水墨风格挺震撼的，献血狂飙也不错
# 4   2018-10-16     4   西安                     我是个粗人，专业点评不会，反正就是看着还可以就给好评了，嘿嘿
# 5   2018-10-16     5   荆州  刚看了电影  《影》人道修罗争权搏杀 砧板上的片肉一样  身体一碰就破 摔跤树枝也能刺破身 ...
# 6   2018-10-16     4  哈尔滨                                      挺好的，就是剧情反转有点尬
# 7   2018-10-16     4   宁海                                         水墨画，结局让人回味
# 8   2018-10-16     5   北京                                             不错不错不错
# 9   2018-10-16     4   深圳                                             还行还行还行
# 10  2018-10-16     4   广州                                      8分不能再多了。差个结局。
# 11  2018-10-16   4.5   东莞                                     着实精彩，就是有点血腥的味道
# 12  2018-10-16   0.5   成都                                         超烂啊！谁看谁后悔！
# 13  2018-10-16     5  阿克苏  《影》评一下，总体来讲还是非常不错的，故事简洁易懂，风格非常的水墨，给人全新的感觉！但不知为...
# 14  2018-10-16   3.5   成都                                      剧情设计得有缺陷，不够合理
#
#             nick gender
# 0   VKg553173023      0
# 1        股海游龙567      1
# 2          成亚801      1
# 3   CWo661915857      1
# 4            記唸式      1
# 5           释迦青慈      0
# 6           万俟薰儿      0
# 7          眉毛断半节      2
# 8          O小贝儿O      0
# 9   QFw281339140      1
# 10  EhF541795161      0
# 11        六六六948      0
# 12  IBO805106935      0
# 13  gzu957747263      0
# 14  cyL801264588      0

# %%
ying = pd.DataFrame(columns=['data','score','city','comment','nick','gender'])
for i in range(0,66):  
    
    try:
        time.sleep(2)
        url = 'http://m.maoyan.com/mmdb/comments/movie/1203437.json?_v_=yes&offset='+str(i*15)
        print(url)
        html = requests.get(url=url, cookies=cookie,headers=header).content.decode('utf-8')
        data = json.loads(html)['cmts']

        for item in data:
            try:
                ying = ying.append({'data':item['time'].split(' ')[0],'city':item['cityName'],
                                                'score':str(item['score']),'comment':item['content'],'nick':item['nick'],'gender':item['gender']},
                                               ignore_index=True)
            except:
                ying = ying.append({'data':item['time'].split(' ')[0],'city':item['cityName'],
                                                'score':str(item['score']),'comment':item['content'],'nick':item['nick'],'gender':0},
                                               ignore_index=True)
    except:
        print("error")
        continue

# %%
ying.to_csv('ying.csv',index=False,encoding="utf_8_sig")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-60a18728d402> in <module>()
# ----> 1 ying.to_csv('ying.csv',index=False,encoding="utf_8_sig")
#
# NameError: name 'ying' is not defined

# %% [markdown]
# ### 热力图

# %%
import pandas as pd
from pyecharts import Bar, Line,Overlap,Geo
import jieba
# from wordcloud import WordCloud,ImageColorGenerator
import matplotlib.pyplot as plt
from collections import Counter

# %%
import numpy as np

# %%
ying = pd.read_csv('ying.csv',encoding="gb18030")

# %%
grouped = ying.groupby(['city'])
grouped_pct = grouped['score']

# %%
city_com = grouped_pct.agg(['mean', 'count'])

# %%
city_com.reset_index(inplace=True)

# %%
city_com['mean'] = round(city_com['mean'], 2)

# %%
data = [(city_com['city'][i], city_com['count'][i]) for i in range(0, city_com.shape[0])]

# %%
geo = Geo('全国热力图', title_color="#fff",title_pos="center", width=1200, height=600, background_color='#404a59')
# attr, value = geo.cast(data)

# %%
attrs=[]
values=[]

# %%
for attr,value in data:
    if geo.get_coordinate(attr)==None:
        continue
    else:
        attrs.append(attr)
        values.append(value)

# %%
geo.add("", attrs, values, type="heatmap",  is_visualmap=True, visual_range=[0, 20],visual_text_color="#fff")
geo.render('全国观影图.html')

# %%
geo
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="354feaed453748e2b0c6bf2374ffbb31" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_354feaed453748e2b0c6bf2374ffbb31 = echarts.init(document.getElementById('354feaed453748e2b0c6bf2374ffbb31'), 'light', {renderer: 'canvas'});
#
# var option_354feaed453748e2b0c6bf2374ffbb31 = {
#     "title": [
#         {
#             "text": "\u5168\u56fd\u70ed\u529b\u56fe",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#fff",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 629174,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": "{b}: {c}",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "heatmap",
#             "coordinateSystem": "geo",
#             "data": [
#                 {
#                     "name": "\u4e09\u4e9a",
#                     "value": [
#                         109.511909,
#                         18.252847,
#                         3.0
#                     ]
#                 },
#                 {
#                     "name": "\u4e09\u6cb3",
#                     "value": [
#                         117.04,
#                         39.58,
#                         1.0
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         35.0
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u865e",
#                     "value": [
#                         120.52,
#                         30.01,
#                         3.0
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u9976",
#                     "value": [
#                         117.58,
#                         25.27,
#                         2.0
#                     ]
#                 },
#                 {
#                     "name": "\u4e1c\u839e",
#                     "value": [
#                         113.75,
#                         23.04,
#                         9.0
#                     ]
#                 },
#                 {
#                     "name": "\u4e1c\u8425",
#                     "value": [
#                         118.49,
#                         37.46,
#                         1.0
#                     ]
#                 },
#                 {
#                     "name": "\u4e1c\u9633",
#                     "value": [
#                         120.14,
#                         29.16,
#                         1.0
#                     ]
#                 },
#                 {
#                     "name": "\u4e2d\u5c71",
#                     "value": [
#                         113.38,
#                         22.52,
#                         8.0
#                     ]
#                 },
#                 {
#                     "name": "\u4e30\u53bf",
#                     "value": [
#                         116.6,
#                         34.7,
#                         1.0
#                     ]
#                 },
#                 {
#                     "name": "\u4e34\u5b89",
#                     "value": [
#                         119.72,
#                         30.23,
#                         2.0
#                     ]
#                 },
#                 {
#                     "name": "\u4e34\u6c7e",
#                     "value": [
#                         111.5,
#                         36.08,
#                         1.0
#                     ]
#                 },
#                 {
#                     "name": "\u4e34\u6c82",
#                     "value": [
#                         118.35,
#                         35.05,
#                         4.0
#                     ]
#                 },
#                 {
#                     "name": "\u4e39\u4e1c",
#                     "value": [
#                         124.37,
#                         40.13,
#                         2.0
#                     ]
#                 },
#                 {
#                     "name": "\u4e39\u9633",
#                     "value": [
#                         119.32,
#                         32,
#                         2.0
#                     ]
#                 },
#                 {
#                     "name": "\u4e49\u4e4c",
#                     "value": [
#                         120.06,
#                         29.32,
#                         1.0
#                     ]
#                 },
#                 {
#                     "name": "\u4e4c\u6d77",
#                     "value": [
#                         106.48,
#                         39.4,
#                         1.0
#                     ]
#                 },
#                 {
#                     "name": "\u4e4c\u9c81\u6728\u9f50",
#                     "value": [
#                         87.68,
#                         43.77,
#                         6.0
#                     ]
#                 },
#                 {
#                     "name": "\u4e50\u5c71",
#                     "value": [
#                         103.44,
#                         29.36,
#                         2.0
#                     ]
#                 },
#                 {
#                     "name": "\u4e50\u6e05",
#                     "value": [
#                         120.58,
#                         28.08,
#                         1.0
#                     ]
#                 },
#                 {
#                     "name": "\u4e5d\u6c5f",
#                     "value": [
#                         115.97,
#                         29.71,
#                         1.0
#                     ]
#                 },
#                 {
#                     "name": "\u4eb3\u5dde",
#                     "value": [
#                         115.47,
#                         33.52,
#                         1.0
#                     ]
#                 },
#                 {
#                     "name": "\u4eea\u5f81",
#                     "value": [
#                         119.1,
#                         32.16,
#                         1.0
#                     ]
#                 },
#                 {
#                     "name": "\u4f0a\u5b81",
#                     "value": [
#                         81.2,
#                         43.55,
#                         1.0
#                     ]
#                 },
#                 {
#                     "name": "\u4f5b\u5c71",
#                     "value": [
#                         113.11,
#                         23.05,
#                         8.0
#                     ]
#                 },
#                 {
#                     "name": "\u510b\u5dde",
#                     "value": [
#                         109.34,
#                         19.31,
#                         1.0
#                     ]
#                 },
#                 {
#                     "name": "\u516d\u5b89",
#                     "value": [
#                         116.28,
#                         31.44,
#                         1.0
#                     ]
#                 },
#                 {
#                     "name

# %% [markdown]
# ### 主要城市评分

# %%
city_main = city_com.sort_values('count',ascending=False)[0:20]

# %%
attr = city_main['city']
v1 = city_main['count']
v2 = city_main['mean']
line = Line("主要城市评分")
line.add("城市", attr, v2, is_stack=True, xaxis_rotate=30, yaxis_min=0, mark_point=["max", "min"], xaxis_interval=0,
         line_color='lightblue', line_width=4, mark_point_textcolor='black', mark_point_color='lightblue', is_splitline_show=False)
bar = Bar("主要城市评论数")
bar.add("城市", attr, v1, is_stack=True, xaxis_rotate=30, yaxis_min=0, xaxis_interval=0, is_splitline_show=False)
overlap = Overlap()
overlap.add(bar)
overlap.add(line, yaxis_index=1, is_add_yaxis=True)
overlap.render('主要城市评分and评论数.html')

# %%
overlap
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="1f78238299a64bec95571bceaa4445b6" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_1f78238299a64bec95571bceaa4445b6 = echarts.init(document.getElementById('1f78238299a64bec95571bceaa4445b6'), 'light', {renderer: 'canvas'});
#
# var option_1f78238299a64bec95571bceaa4445b6 = {
#     "title": [
#         {
#             "text": "\u4e3b\u8981\u57ce\u5e02\u8bc4\u8bba\u6570",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 1183471,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u57ce\u5e02",
#             "data": [
#                 42.0,
#                 35.0,
#                 35.0,
#                 30.0,
#                 30.0,
#                 24.0,
#                 24.0,
#                 23.0,
#                 22.0,
#                 21.0,
#                 16.0,
#                 15.0,
#                 15.0,
#                 15.0,
#                 14.0,
#                 13.0,
#                 13.0,
#                 11.0,
#                 11.0,
#                 10.0
#             ],
#             "stack": "stack_1183471",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 1183471
#         },
#         {
#             "type": "line",
#             "name": "\u57ce\u5e02",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "stack": "stack_3083700",
#             "showSymbol": true,
#             "data": [
#                 [
#                     "\u5317\u4eac",
#                     3.82
#                 ],
#                 [
#                     "\u6df1\u5733",
#                     3.86
#                 ],
#                 [
#                     "\u4e0a\u6d77",
#                     3.86
#                 ],
#                 [
#                     "\u5e7f\u5dde",
#                     3.73
#                 ],
#                 [
#                     "\u6210\u90fd",
#                     4.03
#                 ],
#                 [
#                     "\u90d1\u5dde",
#                     4.02
#                 ],
#                 [
#                     "\u6b66\u6c49",
#                     4.38
#                 ],
#                 [
#                     "\u5357\u4eac",
#                     4.09
#                 ],
#                 [
#                     "\u5929\u6d25",
#                     4.25
#                 ],
#                 [
#                     "\u897f\u5b89",
#                     4.1
#                 ],
#                 [
#                     "\u957f\u6c99",
#                     3.88
#                 ],
#                 [
#                     "\u6c88\u9633",
#                     3.93
#                 ],
#                 [
#                     "\u5927\u8fde",
#                     3.53
#                 ],
#                 [
#                     "\u54c8\u5c14\u6ee8",
#                     4.2
#                 ],
#                 [
#                     "\u6606\u660e",
#                     4.32
#                 ],
#                 [
#                     "\u676d\u5dde",
#                     4.23
#                 ],
#                 [
#                     "\u8d35\u9633",
#                     3.73
#                 ],
#                 [
#                     "\u957f\u6625",
#                     4.41
#                 ],
#                 [
#                     "\u82cf\u5dde",
#                     3.27
#                 ],
#                 [
#                     "\u65e0\u9521",
#                     3.95
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 4,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "lightblue"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "black"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "black"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 1183471,
#             "xAxisIndex": 0,
#             "yAxisIndex": 1
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u57ce\u5e02",
#                 "\u57ce\u5e02"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {

# %% [markdown]
# ### 评分折线图

# %%
city_score = city_main.sort_values('mean',ascending=False)[0:20]
attr = city_score['city']
v1 = city_score['mean']
line = Line('主要城市评分')
line.add("城市", attr, v1, is_stack=True, xaxis_rotate=30, yaxis_min=0, mark_point=["min", "max"], xaxis_interval=0,
         line_color='lightblue', line_width=4, mark_point_textcolor='black', mark_point_color='lightblue', is_splitline_show=True)
line.render('主要城市评分折线图.html')

# %%
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="384c16a05a50464e94cd0f87ec6c0bc3" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_384c16a05a50464e94cd0f87ec6c0bc3 = echarts.init(document.getElementById('384c16a05a50464e94cd0f87ec6c0bc3'), 'light', {renderer: 'canvas'});
#
# var option_384c16a05a50464e94cd0f87ec6c0bc3 = {
#     "title": [
#         {
#             "text": "\u4e3b\u8981\u57ce\u5e02\u8bc4\u5206",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 3933750,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "\u57ce\u5e02",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "stack": "stack_3933750",
#             "showSymbol": true,
#             "data": [
#                 [
#                     "\u957f\u6625",
#                     4.41
#                 ],
#                 [
#                     "\u6b66\u6c49",
#                     4.38
#                 ],
#                 [
#                     "\u6606\u660e",
#                     4.32
#                 ],
#                 [
#                     "\u5929\u6d25",
#                     4.25
#                 ],
#                 [
#                     "\u676d\u5dde",
#                     4.23
#                 ],
#                 [
#                     "\u54c8\u5c14\u6ee8",
#                     4.2
#                 ],
#                 [
#                     "\u897f\u5b89",
#                     4.1
#                 ],
#                 [
#                     "\u5357\u4eac",
#                     4.09
#                 ],
#                 [
#                     "\u6210\u90fd",
#                     4.03
#                 ],
#                 [
#                     "\u90d1\u5dde",
#                     4.02
#                 ],
#                 [
#                     "\u65e0\u9521",
#                     3.95
#                 ],
#                 [
#                     "\u6c88\u9633",
#                     3.93
#                 ],
#                 [
#                     "\u957f\u6c99",
#                     3.88
#                 ],
#                 [
#                     "\u6df1\u5733",
#                     3.86
#                 ],
#                 [
#                     "\u4e0a\u6d77",
#                     3.86
#                 ],
#                 [
#                     "\u5317\u4eac",
#                     3.82
#                 ],
#                 [
#                     "\u5e7f\u5dde",
#                     3.73
#                 ],
#                 [
#                     "\u8d35\u9633",
#                     3.73
#                 ],
#                 [
#                     "\u5927\u8fde",
#                     3.53
#                 ],
#                 [
#                     "\u82cf\u5dde",
#                     3.27
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 4,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "lightblue"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "black"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "black"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 3933750
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u57ce\u5e02"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": 0,
#                 "rotate": 30,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u957f\u6625",
#                 "\u6b66\u6c49",
#                 "\u6606\u660e",
#                 "\u5929\u6d25",
#                 "\u676d\u5dde",
#                 "\u54c8\u5c14\u6ee8",
#                 "\u897f\u5b89",
#                 "\u5357\u4eac",
#                 "\u6210\u90fd",
#                 "\u90d1\u5dde",
#                 "\u65e0\u9521",
#                 "\u6c88\u9633",
#                 "\u957f\u6c99",
#                 "\u6df1\u5733",
#                 "\u4e0a\u6d77",
#                 "\u5317\u4eac",
#                 "\u5e7f\u5dde",
#                 "\u8d35\u9633",
#                 "\u5927\u8fde",
#                 "\u82cf\u5dde"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": t

# %% [markdown]
# ### 全国打分图

# %%
city_score_area = city_com.sort_values('count',ascending=False)[0:100]
city_score_area.reset_index(inplace=True)

data = [(city_score_area['city'][i], city_score_area['mean'][i]) for i in range(0, city_score_area.shape[0])]
attrs=[] 
values=[]
for attr,value in data:
    if geo.get_coordinate(attr)==None:
        continue
    else:
        attrs.append(attr)
        values.append(value)

geo = Geo('全国打分图', title_color="#fff",title_pos="center", width=1200, height=600, background_color='#404a59')

geo.add("", attrs, values, visual_range=[0, 5],visual_text_color="#fff", symbol_size=15, is_visualmap=True,is_roam=False)
geo.render('全国打分图.html')

# %%
geo
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="1f1069eb9a114924acf8ffeb439c42d1" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_1f1069eb9a114924acf8ffeb439c42d1 = echarts.init(document.getElementById('1f1069eb9a114924acf8ffeb439c42d1'), 'light', {renderer: 'canvas'});
#
# var option_1f1069eb9a114924acf8ffeb439c42d1 = {
#     "title": [
#         {
#             "text": "\u5168\u56fd\u6253\u5206\u56fe",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#fff",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 6101949,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": "{b}: {c}",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "scatter",
#             "coordinateSystem": "geo",
#             "symbol": "circle",
#             "symbolSize": 15,
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         3.82
#                     ]
#                 },
#                 {
#                     "name": "\u6df1\u5733",
#                     "value": [
#                         114.07,
#                         22.62,
#                         3.86
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         3.86
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         3.73
#                     ]
#                 },
#                 {
#                     "name": "\u6210\u90fd",
#                     "value": [
#                         104.06,
#                         30.67,
#                         4.03
#                     ]
#                 },
#                 {
#                     "name": "\u90d1\u5dde",
#                     "value": [
#                         113.65,
#                         34.76,
#                         4.02
#                     ]
#                 },
#                 {
#                     "name": "\u6b66\u6c49",
#                     "value": [
#                         114.31,
#                         30.52,
#                         4.38
#                     ]
#                 },
#                 {
#                     "name": "\u5357\u4eac",
#                     "value": [
#                         118.78,
#                         32.04,
#                         4.09
#                     ]
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": [
#                         117.200983,
#                         39.084158,
#                         4.25
#                     ]
#                 },
#                 {
#                     "name": "\u897f\u5b89",
#                     "value": [
#                         108.95,
#                         34.27,
#                         4.1
#                     ]
#                 },
#                 {
#                     "name": "\u957f\u6c99",
#                     "value": [
#                         113,
#                         28.21,
#                         3.88
#                     ]
#                 },
#                 {
#                     "name": "\u6c88\u9633",
#                     "value": [
#                         123.38,
#                         41.8,
#                         3.93
#                     ]
#                 },
#                 {
#                     "name": "\u5927\u8fde",
#                     "value": [
#                         121.62,
#                         38.92,
#                         3.53
#                     ]
#                 },
#                 {
#                     "name": "\u54c8\u5c14\u6ee8",
#                     "value": [
#                         126.63,
#                         45.75,
#                         4.2
#                     ]
#                 },
#                 {
#                     "name": "\u6606\u660e",
#                     "value": [
#                         102.73,
#                         25.04,
#                         4.32
#                     ]
#                 },
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": [
#                         120.19,
#                         30.26,
#                         4.23
#                     ]
#                 },
#                 {
#                     "name": "\u8d35\u9633",
#                     "value": [
#                         106.71,
#                         26.57,
#                         3.73
#                     ]
#                 },
#                 {
#                     "name": "\u957f\u6625",
#                     "value": [
#                         125.35,
#                         43.88,
#                         4.41
#                     ]
#                 },
#                 {
#                     "name": "\u82cf\u5dde",
#                     "value": [
#                         120.62,
#                         31.32,
#                         3.27
#                     ]
#                 },
#                 {
#                     "name": "\u65e0\u9521",
#                     "value": [
#                         120.29,
#                         31.59,
#                         3.95
#                     ]
#                 },
#                 {
#                     "name": "\u5408\u80a5",
#                     "value": [
#                         117.27,
#                         31.86,
#                         4.28
#                     ]
#                 },
#                 {
#                     "name": "\u73e0\u6d77",
#                     "value": [
#                         113.52,
#                         22.3,
#                         3.78
#                     ]
#                 },
#                 {
#                     "name": "\u77f3\u5bb6\u5e84",
#                     "value": [
#                         114.48,
#                         38.03,
#                         4.44
#                     ]
#                 },
#                 {
#                     "name": "\u4e1c\u839e",
#                     "value": [
#                         113.75,
#                         23.04,
#                         4.11
#                     ]
#                 },
#                 {
#                     "name": "\u5b81\u6ce2",
#                     "value": [
#                         121.56,
#                         29.86,
#                         4.06
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": [
#                         106.551556,
#                         29.563009,
#                         3.94
#                     ]
#                 },
#                 {
#                     "name": "\u4e2d\u5c71",
#                     "value": [
#                         113.38,
#                         22.52,

# %% [markdown]
# ### 词云

# %%
from wordcloud import WordCloud,ImageColorGenerator

# %%
ying_str = ' '.join(ying['comment'])

# %%
words_list = []
word_generator = jieba.cut_for_search(ying_str)#似乎word_generator只能被遍历一次

# %%
for word in word_generator:
    words_list.append(word)

# %%
words_list = [k for k in words_list if len(k)>1] #可去除标点

# %%
font_path = "D:\Fonts\simkai.ttf"#字体路径

# %%
wc = WordCloud(
    background_color="white", #背景颜色
    max_words=2000, #显示最大词数
    font_path=font_path,
    min_font_size=15,
    max_font_size=30, 

    )

# %%
# back_color = plt.imread('爱心.jpg')
# wc = WordCloud(background_color='white',
#                mask=back_color,
#                font_path='C:\Windows\Fonts\STZHONGS.TTF',
#                max_words=2000,
#                max_font_size=250,
#                random_state=30,
#                )
love_apartment_count = Counter(words_list)
wc.generate_from_frequencies(love_apartment_count)
# image_colors = ImageColorGenerator(back_color)
plt.figure()
# plt.imshow(wc.recolor(color_func=image_colors))
plt.imshow(wc)
plt.axis('off')
print('生成词云成功!')
wc.to_file('love_apartment.jpg')
# Out:
# 生成词云成功!

# %% [markdown]
# ### 评分星级

# %%
from pyecharts import Pie
import numpy as np

# %%
ying = pd.read_csv('ying.csv',encoding="gb18030")

# %%
#将4.5算作5 ，类似3.5， 2.5， 1.5， 0.5
rate = ying['score']+0.1
rate = rate.apply(np.round)

# %%
value = rate.value_counts()

# %%
# attr = ['五星','四星半', '四星','三星半', '三星','二星半', '二星','一星半', '一星','半星','零星']

# %%
attr = ['五星', '四星', '三星', '二星', '一星','零星']

# %%
pie = Pie('《影》评分星级比例', title_pos='center', width=900)
pie.add('7-17', attr, value, center=[75, 50], is_random=True,
        radius=[30, 75], rosetype='area',
        is_legend_show=False, is_label_show=True)
pie.render('评分.html')

# %%
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="b2ea1051239641ebabbfe28f71dc594c" style="width:900px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_b2ea1051239641ebabbfe28f71dc594c = echarts.init(document.getElementById('b2ea1051239641ebabbfe28f71dc594c'), 'light', {renderer: 'canvas'});
#
# var option_b2ea1051239641ebabbfe28f71dc594c = {
#     "title": [
#         {
#             "text": "\u300a\u5f71\u300b\u8bc4\u5206\u661f\u7ea7\u6bd4\u4f8b",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 4057976,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "name": "7-17",
#             "data": [
#                 {
#                     "name": "\u4e94\u661f",
#                     "value": 537
#                 },
#                 {
#                     "name": "\u56db\u661f",
#                     "value": 252
#                 },
#                 {
#                     "name": "\u4e09\u661f",
#                     "value": 119
#                 },
#                 {
#                     "name": "\u4e8c\u661f",
#                     "value": 58
#                 },
#                 {
#                     "name": "\u4e00\u661f",
#                     "value": 23
#                 },
#                 {
#                     "name": "\u96f6\u661f",
#                     "value": 1
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "75%",
#                 "50%"
#             ],
#             "roseType": "area",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 4057976
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e94\u661f",
#                 "\u56db\u661f",
#                 "\u4e09\u661f",
#                 "\u4e8c\u661f",
#                 "\u4e00\u661f",
#                 "\u96f6\u661f"
#             ],
#             "selectedMode": "multiple",
#             "show": false,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#2a5caa",
#         "#905a3d",
#         "#f6f5ec",
#         "#f05b72",
#         "#f47920",
#         "#ef5b9c",
#         "#749f83",
#         "#ca8622",
#         "#ac6767",
#         "#fab27b",
#         "#2f4554",
#         "#d48265",
#         "#726930",
#         "#444693",
#         "#c23531",
#         "#6d8346",
#         "#546570",
#         "#bda29a",
#         "#61a0a8",
#         "#6950a1",
#         "#c4ccd3",
#         "#6e7074",
#         "#918597",
#         "#b2d235",
#         "#1d953f"
#     ]
# };
# myChart_b2ea1051239641ebabbfe28f71dc594c.setOption(option_b2ea1051239641ebabbfe28f71dc594c);
#
#     });
# </script>
